# %%
import pandas as pd
import numpy as np

# %%
compiled = pd.read_csv('ATL_1941.csv')

# %% [markdown]
# Remove NaN values and replace with empty string

# %%
compiled = compiled.replace(np.nan, '')

# %% [markdown]
# Merge title, abstract and pargraph text and drop those columns

# %%
compiled['original_text'] = compiled['RecordTitle'] + ' ' + compiled['FullText'] + ' ' + compiled['Abstract']
compiled['text'] = compiled['RecordTitle'] + ' ' + compiled['FullText'] + ' ' + compiled['Abstract']
compiled.drop(columns=['RecordTitle', 'FullText', 'Abstract'])
# Out:
#        Unnamed: 0   RecordID            Publisher  AlphaPubDate  \
# 0          135076  490635133  Atlanta Daily World  Jan 31, 1941
# 1          135104  490635186  Atlanta Daily World  Jan 31, 1941
# 2          135143  490635240  Atlanta Daily World  Jan 31, 1941
# 3          135152  490635257  Atlanta Daily World  Jan 31, 1941
# 4          135161  490635272  Atlanta Daily World  Jan 31, 1941
# ...           ...        ...                  ...           ...
# 18492      158389  490673491  Atlanta Daily World   Dec 3, 1941
# 18493      158413  490673534  Atlanta Daily World   Dec 3, 1941
# 18494      158427  490673555  Atlanta Daily World   Dec 3, 1941
# 18495      158447  490673591  Atlanta Daily World   Dec 3, 1941
# 18496      158472  490673632  Atlanta Daily World   Dec 1, 1941
#
#        NumericPubDate              ObjectType StartPage  \
# 0            19410131  Front Page/Cover Story         1
# 1            19410131           Advertisement         3
# 2            19410131        Image/Photograph         1
# 3            19410131  Front Page/Cover Story         1
# 4            19410131                 Article         4
# ...               ...                     ...       ...
# 18492        19411203           Advertisement         2
# 18493        19411203                 Article         3
# 18494        19411203                 Article         4
# 18495        19411203        Image/Photograph         5
# 18496        19411201                 Article         3
#
#                                            original_text  \
# 0      50 BTW Grads Get Diplomas This Evening        ...
# 1      Display Ad 4 -- No Title                      ...
# 2      In 13th Defense                               ...
# 3      MAN, WOMAN FOUND GUILTY OF STABBING           ...
# 4      RACE MEN PROMOTED, TO AID OUR PEOPLE IN JOB SE...
# ...                                                  ...
# 18492  Display Ad 2 -- No Title                      ...
# 18493  Bible Thought                                 ...
# 18494  Birmingham NAACP Meets Thursday               ...
# 18495  "In The Money"                                ...
# 18496  Church News                                   ...
#
#                                                     text
# 0      50 BTW Grads Get Diplomas This Evening        ...
# 1      Display Ad 4 -- No Title                      ...
# 2      In 13th Defense                               ...
# 3      MAN, WOMAN FOUND GUILTY OF STABBING           ...
# 4      RACE MEN PROMOTED, TO AID OUR PEOPLE IN JOB SE...
# ...                                                  ...
# 18492  Display Ad 2 -- No Title                      ...
# 18493  Bible Thought                                 ...
# 18494  Birmingham NAACP Meets Thursday               ...
# 18495  "In The Money"                                ...
# 18496  Church News                                   ...
#
# [18497 rows x 9 columns]

# %% [markdown]
# Reorder columns so `text` is not the final column

# %%
new_cols = ['RecordID','AlphaPubDate','original_text','text']
compiled = compiled[new_cols]

# %% [markdown]
# Get all the punctuation we want to remove

# %%
import string
string.punctuation
# Out:
# '!"#$%&\'()*+,-./:;<=>?@[\\]^_`{|}~'

# %%
import unicodedata

text = compiled['text']
punc_marks = {}
for i in range(len(text)):
    for x in text[i]:
        category = unicodedata.category(x)
        if category[0] == 'P':
            punc_marks[x] = 1

all_punctuation = ''.join(punc_marks)
all_punctuation = all_punctuation + 'â' + '€' + '$' + '~' + '^'
print(all_punctuation)
# Out:
# .:,"-*%\?(')!;]/_{[&#}@â€$~^

# %% [markdown]
# Obtain stopwords dictionary and save all to a list

# %%
import nltk
nltk.download('stopwords')
# Out:
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Unzipping corpora/stopwords.zip.
# True

# %%
from nltk.corpus import stopwords
en_stops = set(stopwords.words('english'))

# %% [markdown]
# Function to remove any non-ascii characters

# %%
def remove_non_ascii(string):
    return ''.join(char for char in string if ord(char) < 128)

# %% [markdown]
# Set all the words to lower case and remove punctuation, numbers, white spaces and non-ascii characters

# %%
text = compiled['text']
for i in range(len(text)):
  graf = '';
  split_text = remove_non_ascii(text[i]).split() #non-ascii
  for word in split_text:
    word = word.lower() #lower case
    word = word.translate(str.maketrans('', '', all_punctuation)) #punctuation
    word = word.strip('0123456789') #numbers
    word = word.strip() #white spaces
    graf = graf + word + ' '
  text[i] = graf
# Out:
# <ipython-input-11-ba3c774ca6c1>:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   text[i] = graf

# %% [markdown]
# Remove all stop words

# %%
for i in range(len(text)):
  graf = '';
  split_text = text[i].split()
  for word in split_text:
    if word not in en_stops:
      graf = graf + word + ' '
  text[i] = graf
# Out:
# <ipython-input-12-4943c0ac51bd>:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   text[i] = graf

# %% [markdown]
# Import the `nltk` packages required for stemming. I tried `PorterStemmer`, `LancasterStemmer` and `WordNetLemmatizer` and found the last to be the most accurate.

# %%
from nltk.stem import PorterStemmer
from nltk.stem import LancasterStemmer
from nltk.tokenize import word_tokenize
from nltk.stem import WordNetLemmatizer

# %% [markdown]
# Download the materials required for the packages to run. `WordNetLemmatizer` utilizes the `wordnet` dictionary.

# %%
nltk.download('punkt')
nltk.download('wordnet')
nltk.download('omw-1.4')
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt.zip.
# [nltk_data] Downloading package wordnet to /root/nltk_data...
# [nltk_data] Downloading package omw-1.4 to /root/nltk_data...
# True

# %% [markdown]
# Stem words using the `WordNetLemmatizer`. Only verbs are stemmed as specified by the `pos` parameter in the `lemmatize` function.

# %%
ps = PorterStemmer()
ls = LancasterStemmer()
wl = WordNetLemmatizer()

for i in range(len(text)):
  graf = '';
  sentence = text[i]
  words = word_tokenize(sentence)
  for word in words:
      graf = graf + wl.lemmatize(word, pos='v') + ' '
  text[i] = graf
# Out:
# <ipython-input-16-d07b549621af>:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   text[i] = graf

# %% [markdown]
# Trying the PorterStemmer...

# %%
for i in range(len(text)):
  graf = '';
  sentence = text[i]
  words = word_tokenize(sentence)
  for word in words:
      graf = graf + ps.stem(word) + ' '
  text[i] = graf
# Out:
# <ipython-input-17-38e21b5617d4>:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   text[i] = graf

# %% [markdown]
# Mount Google Drive and allow access in order to save as csv file.

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# Save as a csv file.

# %%
compiled.to_csv(r'/content/ATL_1941_text.csv')

# %% [markdown]
# Import `collections` package for working with dictionaries.

# %%
import collections

# %% [markdown]
# Calculate word frequencies for each unique word in the file. Frequency increments by 1 if the word is already in the dictionary; otherwise, the word is added and given a frequency of 1.

# %%
unique_words = {}
for i in range(len(text)):
  graf = text[i]
  for word in text[i].split():
    if word in unique_words:
      unique_words[word] += 1
    else:
      unique_words[word] = 1

# %%
classify = compiled['entry']
rv_unique_words = {}
for i in range(len(text)):
  if (classify[i] == 1):
    graf = text[i]
    for word in text[i].split():
      if word in rv_unique_words:
        rv_unique_words[word] += 1
      else:
        rv_unique_words[word] = 1

# %% [markdown]
# Use the `collections` package to list the 50 most common words.

# %%
word_counter = collections.Counter(unique_words)
word_counter.most_common(50)
# Out:
# [('mr', 19545),
#  ('j', 12921),
#  ('c', 6159),
#  ('church', 5534),
#  ('meet', 5329),
#  ('news', 4762),
#  ('r', 4629),
#  ('n', 4592),
#  ('one', 4527),
#  ('w', 4444),
#  ('rev', 4429),
#  ('street', 4366),
#  ('miss', 4068),
#  ('sunday', 3962),
#  ('l', 3946),
#  ('club', 3919),
#  ('say', 3705),
#  ('make', 3694),
#  ('h', 3685),
#  ('new', 3661),
#  ('school', 3511),
#  ('year', 3411),
#  ('presid', 3343),
#  ('negro', 3283),
#  ('u', 3271),
#  ('e', 3247),
#  ('time', 3221),
#  ('atlanta', 3190),
#  ('state', 3143),
#  ('p', 3093),
#  ('b', 2997),
#  ('report', 2985),
#  ('hold', 2962),
#  ('day', 2865),
#  ('home', 2864),
#  ('pm', 2765),
#  ('go', 2703),
#  ('night', 2699),
#  ('dr', 2654),
#  ('v', 2633),
#  ('two', 2629),
#  ('citi', 2572),
#  ('last', 2537),
#  ('baptist', 2408),
#  ('first', 2348),
#  ('man', 2347),
#  ('member', 2338),
#  ('give', 2325),
#  ('st', 2308),
#  ('nbc', 2301)]

# %%
(compiled['entry'] == 1).sum()
# Out:
# 91

# %%
word_counter = collections.Counter(rv_unique_words)
word_counter.most_common(100)
# Out:
# [('j', 150),
#  ('white', 144),
#  ('offic', 131),
#  ('say', 123),
#  ('polic', 112),
#  ('negro', 110),
#  ('color', 103),
#  ('state', 100),
#  ('two', 89),
#  ('man', 87),
#  ('charg', 87),
#  ('lynch', 86),
#  ('mr', 84),
#  ('n', 80),
#  ('make', 78),
#  ('case', 78),
#  ('c', 78),
#  ('report', 76),
#  ('court', 72),
#  ('one', 71),
#  ('new', 71),
#  ('mob', 65),
#  ('men', 65),
#  ('feder', 65),
#  ('street', 63),
#  ('juri', 60),
#  ('citi', 59),
#  ('investig', 59),
#  ('take', 56),
#  ('beat', 55),
#  ('last', 53),
#  ('r', 51),
#  ('u', 50),
#  ('right', 50),
#  ('night', 48),
#  ('find', 48),
#  ('peopl', 47),
#  ('counti', 46),
#  ('continu', 45),
#  ('arrest', 45),
#  ('w', 45),
#  ('death', 44),
#  ('shoot', 44),
#  ('boy', 43),
#  ('day', 42),
#  ('jail', 42),
#  ('year', 42),
#  ('victim', 42),
#  ('woman', 41),
#  ('sever', 40),
#  ('indict', 40),
#  ('klan', 39),
#  ('three', 39),
#  ('come', 39),
#  ('home', 39),
#  ('member', 38),
#  ('time', 38),
#  ('citizen', 38),
#  ('nation', 38),
#  ('ol', 38),
#  ('atlanta', 38),
#  ('attorney', 37),
#  ('naacp', 37),
#  ('judg', 37),
#  ('trial', 36),
#  ('would', 36),
#  ('bodi', 36),
#  ('south', 35),
#  ('e', 35),
#  ('head', 35),
#  ('h', 35),
#  ('associ', 35),
#  ('sunday', 34),
#  ('person', 34),
#  ('sentenc', 34),
#  ('town', 34),
#  ('law', 34),
#  ('l', 34),
#  ('week', 33),
#  ('friday', 33),
#  ('bill', 33),
#  ('order', 33),
#  ('f', 33),
#  ('justic', 33),
#  ('give', 33),
#  ('^', 32),
#  ('school', 32),
#  ('grand', 32),
#  ('depart', 32),
#  ('murder', 31),
#  ('kill', 31),
#  ('morn', 31),
#  ('local', 30),
#  ('tri', 30),
#  ('place', 30),
#  ('get', 30),
#  ('william', 29),
#  ('follow', 29),
#  ('women', 29),
#  ('burn', 29)]

# %% [markdown]
# How many times does the word *black* appear?

# %%
unique_words.get('black')
# Out:
# 270

# %%
rv_unique_words.get('black')
# Out:
# 1

# %%
rv_unique_words.get('negro')
# Out:
# 42

# %%
rv_unique_words.get('color')
# Out:
# 48

# %% [markdown]
# How many times does the word *white* appear?

# %%
unique_words.get('white')
# Out:
# 1009

# %%
rv_unique_words.get('white')
# Out:
# 77

# %% [markdown]
# for my own use :)

# %%
compiled['text'].head(50)
# Out:
# 0     weather titl weather fa colder tempera fcnr rf...
# 1     mr mason speaker forum tonight mr mason speake...
# 2     georgia death georgia death mr annik klxti cay...
# 3     jc smith top shaw five jc smith top shaw five ...
# 4     emot factor disea emot factor disea ftv rnoar ...
# 5     railway cross colli result death pair railway ...
# 6     antilynch bill sidelight antilynch bill sideli...
# 7     david howard hi sponsor richard durant recit d...
# 8     fear freez record snow coat fear freez record ...
# 9     henri bracken bracken oa henri bracken pass aw...
# 10    harlem trivia harlem trivia marguerit l martin...
# 11    radio program radio program waga yawn patrol o...
# 12    sam auburn avenu say auburn avenu say ry ip ix...
# 13    wish well wish hike u littl tame win give y^l ...
# 14    classifi ad titl classifi rent room h mitehil ...
# 15    self make girl sbf make l hazel ~f livfngston ...
# 16    articl titl earc popular fonner assist manag a...
# 17    belov yearold memphian dead belov year0ld memp...
# 18    civil servic examin announc civil servic exami...
# 19    billi duncan ring success buffalo n billi dunc...
# 20    alleg coal thief catch polic alleg coal thief ...
# 21    fur hat domin fashion winter fur hat domin fas...
# 22    alabama bag fisk hairrai alabama bag fisk hair...
# 23    mansfield ga mansfield ga iren bank mansfield ...
# 24    railway schedul railway schedul central standa...
# 25    high school game put indefinit high school gam...
# 26    marriag announc titl sdimon valdosta ga mr ann...
# 27    state nation state nation tile presid submit b...
# 28                   weather titl weather ~fade aid vt
# 29    plan chime mercer honor decea servant plan chi...
# 30    snow bog court machineri snow bog court machin...
# 31    madison high cager win doublehead madison high...
# 32    joe loui attend danc battl joe loui attend dan...
# 33    person person mr detroit mich spend mtt urith ...
# 34                  weather titl weather w cloudi wash
# 35    fraley convict bug apart oper fraley convict b...
# 36    florida sacksdegan score florida sack degan sc...
# 37    court order rev jackson vacat court order rev ...
# 38    hold six race men mail theft ring hold six rac...
# 39    learn use busi machin student warn learn use b...
# 40    red earth jbedewnh ^tom gill chapter xxxii wit...
# 41    hunter terrac commun club interest meet hunter...
# 42    adelphi trio clash tomorrow adeiphi trio clash...
# 43    adelphidthh btwhsnooga tonit adelphi nooga ton...
# 44    americu ga americu ga j anderson jr ga willi w...
# 45    wish well ^pr^~^^ ^ ~^ pleasant littl game giv...
# 46    mr mari frazier mr mari dorta ga mr mari frszt...
# 47    hold stab hold stab citi ^ wednesday report ar...
# 48                      josnua ~mmmm f ^^h + mm ^m^^^m
# 49    red cap theyr transport servic employ red cap ...
# Name: text, dtype: object
